# %%
from matplotlib_venn import venn3
from matplotlib import pyplot as plt

# %%
def drawVenn3(A,B,C,labels = ('A', 'B', 'C')):
    '''
    listing elements in Venn diagram of three sets, A, B, C
    '''
    v3=venn3([A,B,C],set_labels = labels)
    if A-B-C:
        v3.get_label_by_id('100').set_text('\n'.join(map(str,A-B-C)))
        v3.get_patch_by_id('100').set_alpha(0.6)
        v3.get_patch_by_id('100').set_facecolor('Yellow')
    if A&B-C:
        v3.get_label_by_id('110').set_text('\n'.join(map(str,A&B-C)))
        v3.get_patch_by_id('110').set_alpha(0.3)
        v3.get_patch_by_id('110').set_facecolor('Red')
    if B-C-A:
        v3.get_label_by_id('010').set_text('\n'.join(map(str,B-C-A)))
        v3.get_patch_by_id('010').set_alpha(0.6)
        v3.get_patch_by_id('010').set_facecolor('Magenta')
    if A&C-B:
        v3.get_label_by_id('101').set_text('\n'.join(map(str,A&C-B)))
        v3.get_patch_by_id('101').set_alpha(0.3)
        v3.get_patch_by_id('101').set_facecolor('Green')
    if A&B&C:
        v3.get_label_by_id('111').set_text('\n'.join(map(str,A&B&C)))
        v3.get_patch_by_id('111').set_alpha(0.1)
        v3.get_patch_by_id('111').set_facecolor('Black')
    if B&C-A:
        v3.get_label_by_id('011').set_text('\n'.join(map(str,B&C-A)))
        v3.get_patch_by_id('011').set_alpha(0.3)
        v3.get_patch_by_id('011').set_facecolor('Blue')
    if C-B-A:
        v3.get_label_by_id('001').set_text('\n'.join(map(str,C-B-A)))
        v3.get_patch_by_id('001').set_alpha(0.6)
        v3.get_patch_by_id('001').set_facecolor('Cyan')

# %% [markdown]
# # 1. In a Survey of 120 People, it was found that:
# - 65 read Newsweek Magazine
# - 45 read Times Magazine
# - 42 read Fortune Magazine
# - 20 read Both Newsweek and Time
# - 25 read both Newsweek and Fortune
# - 15 read both Time and Fortune
# - 8 read all three magazines

# %% [markdown]
# It stated that:
# - 65 read Newsweek Magazine: $|N|$ = 65
# - 45 read Times Magazine: $|T|$ = 45
# - 42 read Fortune Magazine: $|F|$ = 42
#
# But that doesn't mean it's "only people who read that $N$ magazine" meaning that, that number is the combination of various other people who also read 1 or more magazines. therefore:
#
# - $|N|$ - $|N \cap T|$ - $|N \cap F|$ -  $|N \cap T \cap F|$
# - $|T|$ - $|T \cap N|$ - $|T \cap F|$ -  $|T \cap N \cap F|$
# - $|F|$ - $|F \cap N|$ - $|F \cap T|$ -  $|F \cap T \cap N|$
#
# although the $|x \cap x|$ are also not the only people who read "x and y" as the people who read all 3 magazines is also combined in the intersection, therefore we firslly need to subtract it to the people who read all 3 magazines:
#
# - $|N \cap T|$ - $|N \cap T \cap F|$: 20 - 8: 12 so $|N \cap T|$ is equals to $\boxed{12}$
# - $|F \cap N|$ - $|F \cap T \cap N|$: 25 - 8: 17 so $|F \cap N|$ is equals to $\boxed{17}$
# - $|T \cap F|$ - $|T \cap N \cap F|$: 15 - 8: 7 so $|T \cap F|$ is equals to $\boxed{7}$
#
# after we have the actual values of the intersections $|x \cap x|$, then we now subtract it along with the people who read all three magazines to the given people who "read" the $x$ magazine
#
# - $|N|$ - $|N \cap T|$ - $|N \cap F|$ -  $|N \cap T \cap F|$: $|N|$ = $\boxed{12} - \boxed{17} - \boxed{8}$: $\boxed{28}$
# - $|T|$ - $|T \cap N|$ - $|T \cap F|$ -  $|T \cap N \cap F|$: $|T|$ = $\boxed{12} - \boxed{7} - \boxed{8}$: $\boxed{18}$
# - $|F|$ - $|F \cap N|$ - $|F \cap T|$ -  $|F \cap T \cap N|$: $|F|$ = $\boxed{17} - \boxed{7} - \boxed{8}$: $\boxed{10}$
#
# and if we place our now changed values to a venn diagram, it looks like this:

# %%
N = 28
T = 18
F = 10
NF = 17 
NT = 12
TF = 7 
NTF = 8

venn3(subsets=(N, T, NT, F, NF, TF, NTF), set_labels=('Newsweek Magazine', 'Times Magazine', 'Fortune Magazine'))

plt.show()

# %% [markdown]
# ### 2. In a survey of 25 new cars being sold at a local auto dealer was conducted to see which of the three popular options: air-conditioning, denoted as A; radio, denoted as R; and power windows, denoted as W were installed. The survey found that: - 15 had A. - 12 had R. - 11 had W. - 5 had A and W. - 9 had A and R. - 4 had R and W. - Only 3 hace the three options. With these information do the following:

# %% [markdown]
# 1. Draw the venn diagram using python.
#
# So they stated that:

# %%
A = 15
R = 12
W = 11
AW = 5
AR = 9
RW = 4
ARW = 3

# %% [markdown]
# But the values of "$A$, $R$, and $W$ are not entirely true as it did not mean that only these people are the ones that have the $x$ installed, much like the intersections of the three: "$A \cap W$, $A \cap R$, and $R \cap W$ are not entirely true as it did not specify that only these people have installed $x$ and $y$ and that it also includes people who have 3 pf them installed, therefore:

# %% [markdown]
# $A = ((A \cap R - A \cap R \cap W) + (A \cap W - A \cap R \cap W) + A \cap R \cap W)$
# - A = 15 - ((9 - 3) + (5 - 3) + 3)
# - A = 15 - (6 + 2 + 3)
# - A = 15 - 11
# - A = $\boxed{4}$

# %%
A = 4

# %% [markdown]
# $R = ((A \cap R - A \cap R \cap W) + (R \cap W - A \cap R \cap W) + A \cap R \cap W)$
# - R = 12 - ((9 - 3) + (4 - 3) + 3)
# - R = 12 - (6 + 1 + 3)
# - R = 12 - 10
# - R = $\boxed{2}$

# %%
R = 2

# %% [markdown]
# $W = ((A \cap W - A \cap R \cap W) + (R \cap W - A \cap R \cap W) + A \cap R \cap W)$
# - W = 11 - ((5 - 3) + (4 - 3) + 3)
# - W = 11 - (2 + 1 + 3)
# - W = 11 - 6
# - W = $\boxed{5}$

# %%
W = 5

# %% [markdown]
# we also need to subtract the intersections "$|x \cap x|$" with "$|A \cap R \cap W|$", so..

# %% [markdown]
# - AW = AW - ARW
# - AW = 5 - 3
# - AW = $\boxed{2}$

# %%
AW = 2

# %% [markdown]
# - AR = AR - ARW
# - AR = 9 - 3
# - AR = $\boxed{6}$

# %%
AR = 6

# %% [markdown]
# - RW = RW - ARW
# - RW = 4 - 3
# - RW = $\boxed{1}$

# %%
RW = 1

# %%
venn3(subsets=(A, R, AR, W, AW, RW, ARW), set_labels=('Air-contioning', 'Radio', 'Power-windows'))

plt.show()

# %%
# For number 2 questions

UNCHNGD_A = 15
UNCHNGD_R = 12
UNCHNGD_W = 11
UNCHNGD_AW = 5
UNCHNGD_AR = 9
UNCHNGD_RW = 4
UNCHNGD_ARW = 3

# %% [markdown]
# 2. Find the number of cars with W only.

# %%
chngd_W = UNCHNGD_W - ((UNCHNGD_RW - UNCHNGD_ARW) + (UNCHNGD_AW - UNCHNGD_ARW) + UNCHNGD_ARW)
# chngd_W = 11 - ((4 - 3) + (5 - 3) + 3)
# chngd_W = 11 - (1 + 2 + 3)
# chngd_W = 11 - 6
# chngd_W = 5
print("Number of cars with W only:", chngd_W)# reutrns 5
# Out:
# Number of cars with W only: 5

# %% [markdown]
# 3. Find the number of cars with A only.

# %%
chngd_A = UNCHNGD_A - ((UNCHNGD_AW - UNCHNGD_ARW) + (UNCHNGD_AR - UNCHNGD_ARW) + UNCHNGD_ARW)
# chngd_A = 15 - ((5 - 3) + (9 - 3) + 3)
# chngd_A = 15 - (2 + 6 + 3)
# chngd_A = 15 - 11
# chngd_A = 4
print("Number of cars with W only:", chngd_A)# reutrns 4
# Out:
# Number of cars with W only: 4

# %% [markdown]
# 4. Find the number of cars with R only.

# %%
chngd_R = UNCHNGD_R - ((UNCHNGD_AR - UNCHNGD_ARW) + (UNCHNGD_RW - UNCHNGD_ARW) + UNCHNGD_ARW)
# chngd_R = 12 - ((9 - 3) + (4 - 3) + 3)
# chngd_R = 12 - (6 + 1 + 3)
# chngd_R = 12 - 10
# chngd_R = 2
print("Number of cars with R only:", chngd_R) # returns 2
# Out:
# Number of cars with R only: 2

# %% [markdown]
# 5.  Find the number of cars with both R and W but not A.

# %%
chngd_RW = UNCHNGD_RW - UNCHNGD_ARW
# chngd_RW = 4 - 3
# chngd_RW = 1
print("Number of cars with both R and W but not A:", chngd_RW) # returns 1
# Out:
# Number of cars with both R and W but not A: 1

# %% [markdown]
# 6. Find the number of cars with both A and R but not W.

# %%
chngd_AR = UNCHNGD_AR - UNCHNGD_ARW
# chngd_AR = 9 - 3
# chngd_AR = 6
print("Number of cars with both A and R but not W:", chngd_AR)# returns 6
# Out:
# Number of cars with both A and R but not W: 6

# %% [markdown]
# 7. Find the number of cars with only one of the options.

# %%
only_one_option = ((UNCHNGD_W - ((UNCHNGD_RW - UNCHNGD_ARW) + (UNCHNGD_AW - UNCHNGD_ARW) + UNCHNGD_ARW))
                + (UNCHNGD_A - ((UNCHNGD_AW - UNCHNGD_ARW) + (UNCHNGD_AR - UNCHNGD_ARW) + UNCHNGD_ARW))
                + (UNCHNGD_R - ((UNCHNGD_AR - UNCHNGD_ARW) + (UNCHNGD_RW - UNCHNGD_ARW) + UNCHNGD_ARW)))
# only_one_option = ((11 - ((4 - 3) + (5 - 3) + 3)) + (15 - ((5 - 3) + (9 - 3) + 3)) + (12 - ((9 - 3) + (4 - 3) + 3)))
# only_one_option = ((11 - (1 + 2 + 3)) + (15 - (2 + 6 + 3)) + (12 - (6 + 1 + 3)))
# only_one_option = ((11 - 6) + (15 - 11) + (12 - 10))
# only_one_option = (5 + 4 + 2)
# only_one_option = 11
print("Number of cars with only one of the options:", only_one_option) # returns 11
# Out:
# Number of cars with only one of the options: 11

# %% [markdown]
# 8. Find the number of cars with at least one option.

# %%
at_least_one_option = ((UNCHNGD_W - ((UNCHNGD_RW - UNCHNGD_ARW) + (UNCHNGD_AW - UNCHNGD_ARW) + UNCHNGD_ARW))
                + (UNCHNGD_A - ((UNCHNGD_AW - UNCHNGD_ARW) + (UNCHNGD_AR - UNCHNGD_ARW) + UNCHNGD_ARW))
                + (UNCHNGD_R - ((UNCHNGD_AR - UNCHNGD_ARW) + (UNCHNGD_RW - UNCHNGD_ARW) + UNCHNGD_ARW))) + ((UNCHNGD_AR - UNCHNGD_ARW) + (UNCHNGD_AW - UNCHNGD_ARW) + (UNCHNGD_RW - UNCHNGD_ARW))+ (UNCHNGD_ARW)


print("Number of cars with at least one option:", at_least_one_option)
# Out:
# Number of cars with at least one option: 23

# %% [markdown]
# 9. Find the number of cars with none of the Options.

# %%
none_of_the_options = 25 - at_least_one_option
print("Number of cars with none of the options:", none_of_the_options)
# Out:
# Number of cars with none of the options: 2
